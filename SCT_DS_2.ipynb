# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df = pd.read_csv("titanic_dataset.csv")

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (915, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  915 non-null    int64
#  1   Pclass    915 non-null    int64
#  2   Name      915 non-null    object
#  3   Sex       915 non-null    object
#  4   Age       735 non-null    float64
#  5   SibSp     915 non-null    int64
#  6   Parch     915 non-null    int64
#  7   Ticket    915 non-null    object
#  8   Fare      915 non-null    float64
#  9   Cabin     209 non-null    object
#  10  Embarked  913 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 78.8+ KB

# %%
# Data cleaning
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop(columns=['Cabin'], inplace=True)

# %%
# Summary statistics
print(df.describe())
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  915.000000  915.000000  915.000000  915.000000  915.000000  915.000000
# mean     0.389071    2.307104   29.376142    0.532240    0.390164   32.062631
# std      0.487806    0.834633   13.081513    1.125495    0.820759   49.312772
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.925000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   30.847900
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Age distribution
plt.figure()
plt.hist(df['Age'], bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution of Passengers")
plt.show()

# %%
# Survival distribution
survival_counts = df['Survived'].value_counts()
plt.figure()
plt.bar(survival_counts.index.astype(str), survival_counts.values)
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Number of Passengers")
plt.title("Survival Distribution")
plt.show()

# %%
# Fare distribution
plt.figure()
plt.hist(df['Fare'], bins=20)
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.title("Fare Distribution")
plt.show()

# %%
# Passenger class distribution
class_counts = df['Pclass'].value_counts().sort_index()
plt.figure()
plt.bar(class_counts.index.astype(str), class_counts.values)
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Passenger Class Distribution")
plt.show()
